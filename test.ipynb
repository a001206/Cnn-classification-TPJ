# %% [markdown]
# <a href="https://colab.research.google.com/github/a001206/Cnn-classification-TPJ/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import keras
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Dense

# %%
word = 'Haesung'

# %%
type(word)
# Out:
# str

# %%
x = [10,20,30,40,50,60,70,80]

# %% [markdown]
# 슬라이싱

# %%
x[0:4]
# Out:
# [10, 20, 30, 40]

# %%
x[3:]
# Out:
# [40, 50, 60, 70, 80]

# %% [markdown]
# 처음부터 -3까지 가져오기

# %%
x[:-3]
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# **numpy**
# 머신러닝 딥러닝에 사용하기 위해선 array로 변환해줘야함.

# %%
import numpy as np

# %%
np.array(x)
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80])

# %%
type(x)
# Out:
# list

# %% [markdown]
# n차원의 array이다

# %%
type(np.array(x))
# Out:
# numpy.ndarray

# %%
x_arr =  np.array(x)

# %%
x_arr.shape
# Out:
# (8,)

# %%
x_2d = [[10,20,30,40],[50,60,70,80]]

# %%
x_2d_arr = np.array(x_2d)

# %%
x_2d_arr.shape
# Out:
# (2, 4)

# %%
x_3d = [
        [[],[]],
        [[],[]]
]

# %%
for i in 'Haesung':
  print(i)
# Out:
# H
# a
# e
# s
# u
# n
# g

# %%
fig, ax = plt.subplots(2,3)
grid = plt.GridSpec(2,3 , wspace=0.4, hspace=0.3)
X = np.random.random(100)
Y = np.random.random(100)
plt.subplot(grid[0,0]).scatter(X,Y)

X = np.arange(10)
Y = np.random.uniform(1,10,10)
plt.subplot(grid[0,1:]).bar(X,Y)


# plt.subplot(grid[0,1:].bar(X,Y))
# Out:
# <BarContainer object of 10 artists>

# %%
x = np.linspace(0,np.pi*2,100)

fig = plt.figure()

plt.plot(x, np.sin(x), 'r-')
plt.plot(x, np.cos(x), 'b:')

fig.savefig('sin_cos_fig.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
N =30 
x = np.random.rand(N)
y = np.random.rand(N)

colors = np.random.rand(N)
area = (30*np.random.rand(N))**2
plt.scatter(x,y,s = area, c =colors, alpha=0.4)

# %%
x = np.arange(3)
years = ['2010', '2011', '2012']
domestic = [6801,7695,8010]
foreign = [777,1046,1681]

plt.bar(x,domestic, width =0.25)
plt.bar(x+ 0.3,foreign, width =0.25)
plt.xticks(x,years)
# Out:
# ([<matplotlib.axis.XTick at 0x7f0633bf4110>,
# ...
#  [Text(0, 0, '2010'), Text(0, 0, '2011'), Text(0, 0, '2012')])

# %%
data = [3,7,2,7]
clist = ['cyan', 'red', 'orange', 'gray']
plt.pie(data, autopct = '%.2f', colors =clist)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f063420b650>,
# ...
#  [Text(0.9674211366466224, 0.5235421132720434, ''),
#   Text(-0.6016429240182313, 0.9208831587008163, ''),
#   Text(-0.9674211611553967, -0.5235420679837907, ''),
#   Text(0.44186488769512783, -1.0073506941587782, '')],
#  [Text(0.5276842563527031, 0.28556842542111455, '15.79'),
#   Text(-0.3281688676463079, 0.5022999047458997, '36.84'),
#   Text(-0.5276842697211254, -0.28556840071843126, '10.53'),
#   Text(0.2410172114700697, -0.5494640149956971, '36.84')])

# %%
data = [3,7,2,7]
clist = ['cyan', 'red', 'orange', 'gray']
explode = [.06, .07, .08, .09]
plt.pie(data, autopct = '%.2f', colors =clist, labels=clist, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0634345790>,
# ...
#  [Text(1.0201895622818928, 0.5520989558141548, 'cyan'),
#   Text(-0.6399292919103006, 0.9794848142545046, 'red'),
#   Text(-1.03777906378488, -0.5616178547462481, 'orange'),
#   Text(0.4780174694156383, -1.0897702964081328, 'gray')],
#  [Text(0.5804526819879734, 0.314125267963226, '15.79'),
#   Text(-0.3664552355383772, 0.560901560299588, '36.84'),
#   Text(-0.5980421723506087, -0.32364418748088875, '10.53'),
#   Text(0.27716979319058016, -0.6318836172450517, '36.84')])

# %%
data = np.random.random((10,10))
plt.imshow(data, cmap = 'cool')
plt.colorbar()
print(data[0])
# Out:
# [0.59473559 0.69870246 0.11403744 0.43201506 0.32836373 0.30496676
#  0.01391616 0.79085781 0.92989829 0.17620403]

# %%
height = np.random.randint(160,180, size = 30)
plt.hist(height, bins = 6)
plt.xlabel("height")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
import seaborn as sns
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

np.random.seed(85)
x = np.arange(0, 10)
y1 = x*2
y2 = x**3
y3 = np.random.randint(0,100,size =10)

result = np.corrcoef((x,y2,y3))

plt.imshow(result)
plt.colorbar()
print(y2)
# df = pd.DataFrame({'x': x, 'y': y, 'y3': y3})
# sns.pairplot(df)
# Out:
# [  0   1   8  27  64 125 216 343 512 729]

# %%
import seaborn as sns
import pandas as pd
df = pd.DataFrame({'x':x, 'y2':y2, 'y3':y3})
sns.pairplot(df)

# %%
sns.set_theme(style = "darkgrid")
tips = sns.load_dataset("tips")
sns.relplot(data = tips, x = "total_bill", y = "tip", col = "time", hue = "smoker", style = "smoker", size = "size")

# %%
tips.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.distplot(tips['tip'], kde = False, bins = 10);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
tips['tip_pct'] = 100 *tips['tip'] / tips['total_bill']
sns.distplot(tips['tip_pct'], kde = True, bins = 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.regplot(data = tips , x = 'total_bill', y = 'tip')
ax.set_xlabel('Total_bill')
ax.set_ylabel('Tip')
ax.set_title('Total Bill and Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill and Tip')

# %%
sns.pairplot(tips, kind = 'hist')

# %%
anscombe = sns.load_dataset('anscombe')
print(anscombe.head())
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
import numpy as np

a = np.array([[1,1],[2,2],[3,3]])
np.insert(a, 1, 5)
# Out:
# array([1, 5, 1, 2, 2, 3, 3])
